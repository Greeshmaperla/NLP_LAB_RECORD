# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB_RECORD/blob/main/bendingpost_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tag import brill, brill_trainer

# Training data
data = [[('The','DT'),('dog','NN'),('barks','VBZ')],
        [('A','DT'),('cat','NN'),('meows','VBZ')]]

# Base tagger
base = nltk.UnigramTagger(data)

# Train Brill tagger
tagger = brill_trainer.BrillTaggerTrainer(base, brill.fntbl37()).train(data)

# Test
print(tagger.tag(['The','cat','barks']))
# Out:
# [('The', 'DT'), ('cat', 'NN'), ('barks', 'VBZ')]
