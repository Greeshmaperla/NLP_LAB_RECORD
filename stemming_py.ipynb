# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB_RECORD/blob/main/stemming_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import PorterStemmer

# Create a PorterStemmer object
stemmer = PorterStemmer()

# List of words to stem
words = ["running", "jumps", "easily", "fairly"]

# Apply stemming to each word
stemmed_words = [stemmer.stem(word) for word in words]

# Print the original and stemmed words
for original, stemmed in zip(words, stemmed_words):
    print(f"{original}  -->  {stemmed}")
# Out:
# running  -->  run
# jumps  -->  jump
# easily  -->  easili
# fairly  -->  fairli
