# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB_RECORD/blob/main/pos_tagging_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load the small English model
nlp = spacy.load("en_core_web_sm")

# Input sentence
text = "The quick brown fox jumps over the lazy dog."

# Process the text
doc = nlp(text)

# Print word and its POS tag
for token in doc:
    print(token.text, "→", token.pos_)
# Out:
# The → DET
# quick → ADJ
# brown → ADJ
# fox → NOUN
# jumps → VERB
# over → ADP
# the → DET
# lazy → ADJ
# dog → NOUN
# . → PUNCT
