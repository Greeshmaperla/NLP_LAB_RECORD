# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB_RECORD/blob/main/normalization_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
text = "Here's an example: NORMALIZATION & NLP!!! 123 :)"

text = text.lower()
text = re.sub(r'[^a-z\s]', '', text)
text = re.sub(r'\s+', ' ', text).strip()

print(text)
# Out:
# heres an example normalization nlp
