# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmaperla/NLP_LAB_RECORD/blob/main/HMM_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tag import hmm

train = [[('The','DT'),('dog','NN'),('barks','VBZ')],
         [('A','DT'),('cat','NN'),('meows','VBZ')]]

tagger = hmm.HiddenMarkovModelTrainer().train_supervised(train)
print(tagger.tag(['A','dog','meows']))
# Out:
# [('A', 'DT'), ('dog', 'NN'), ('meows', 'VBZ')]
